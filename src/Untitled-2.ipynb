# %%
import sys
import os

name = "20220909-055845-10-10-50-10-100-500-0-0.0-1000.0-1.0-2.0-5.0-0.1"

if 'plotting' in sys.modules:  
    del sys.modules["plotting"]

from plotting import * 

method_list = ['TS-Bayes_errors','TS-Bayes_lambda_mins', 'TS-Bayes_lambda_maxs','TS-Bayes_log_maxs_over_mins', 'TS-Bayes_thinnesses',  'TS-Bayes_lambdas_second', 'TS-Bayes_lambdas_third', 'TS-Bayes_biases', 'TS-Bayes_variances','TS-Bayes_risks']



for method in method_list:
    save_path = f'../plots35/{method}/'
    isExist = os.path.exists(save_path)
    if not isExist:
        os.makedirs(save_path)

    df = pd.read_csv(f'../plots/all-unit-last-{name}.csv')
    plot_last_iter(df,'d' ,method,'d','y','k',save_path+name+'-1.jpg' )

    df = pd.read_csv(f'../plots/all-unit-{name}.csv')
    plot_sample_path(df, 'd', method, 't', 'y', 'd', 'k', save_path, f'{name}-2.jpg', 1)
# Out:
# [  1   3  10  50 100]
# index: 1,  x: [10 20 30 40 50], y: [0.00997822 0.00561779 0.00424628 0.00296558 0.0022971 ], se: [0.00213377 0.00061495 0.00033825 0.00020437 0.00016666]
# index: 3,  x: [10 20 30 40 50], y: [0.03643133 0.01742433 0.01011238 0.00726917 0.00622425], se: [0.00599774 0.00265983 0.00069441 0.00055643 0.00027621]
# index: 10,  x: [10 20 30 40 50], y: [0.076989   0.03986904 0.02421634 0.01925671 0.01659575], se: [0.00790271 0.00317228 0.00249887 0.00132988 0.0007469 ]
# index: 50,  x: [10 20 30 40 50], y: [0.22603612 0.13245638 0.07612879 0.06266307 0.04625818], se: [0.01986774 0.00777365 0.00636864 0.00455577 0.00245553]
# index: 100,  x: [10 20 30 40 50], y: [0.36133003 0.19639393 0.15315195 0.1177125  0.09405483], se: [0.04823404 0.01304062 0.01648886 0.00960113 0.00804395]
# [  1   3  10  50 100]
# index: 1,  x: [10 20 30 40 50], y: [ 56.80767073 103.59034567 151.60888506 196.80363801 244.7298129 ], se: [2.05934818 2.50124338 1.50856251 2.89102317 1.90728126]
# ...

# %%
import sys
import os

name = "20220909-061030-10-10-50-10-100-500-0-0.0-1000.0-1.0-2.0-5.0-0.1"

if 'plotting' in sys.modules:  
    del sys.modules["plotting"]

from plotting import * 

method_list = ['TS-Bayes_errors','TS-Bayes_lambda_mins', 'TS-Bayes_lambda_maxs','TS-Bayes_log_maxs_over_mins', 'TS-Bayes_thinnesses',  'TS-Bayes_lambdas_second', 'TS-Bayes_lambdas_third', 'TS-Bayes_biases', 'TS-Bayes_variances','TS-Bayes_risks']



for method in method_list:
    save_path = f'../plots36/{method}/'
    isExist = os.path.exists(save_path)
    if not isExist:
        os.makedirs(save_path)

    df = pd.read_csv(f'../plots/all-unit-last-{name}.csv')
    plot_last_iter(df,'d' ,method,'d','y','k',save_path+name+'-1.jpg' )

    df = pd.read_csv(f'../plots/all-unit-{name}.csv')
    plot_sample_path(df, 'd', method, 't', 'y', 'd', 'k', save_path, f'{name}-2.jpg', 1)
# Out:
# [  1   3  10  50 100]
# index: 1,  x: [10 20 30 40 50], y: [0.00997822 0.00561779 0.00424628 0.00296558 0.0022971 ], se: [0.00213377 0.00061495 0.00033825 0.00020437 0.00016666]
# index: 3,  x: [10 20 30 40 50], y: [0.03643133 0.01742433 0.01011238 0.00726917 0.00622425], se: [0.00599774 0.00265983 0.00069441 0.00055643 0.00027621]
# index: 10,  x: [10 20 30 40 50], y: [0.076989   0.03986904 0.02421634 0.01925671 0.01659575], se: [0.00790271 0.00317228 0.00249887 0.00132988 0.0007469 ]
# index: 50,  x: [10 20 30 40 50], y: [0.22603612 0.13245638 0.07612879 0.06266307 0.04625818], se: [0.01986774 0.00777365 0.00636864 0.00455577 0.00245553]
# index: 100,  x: [10 20 30 40 50], y: [0.36133003 0.19639393 0.15315195 0.1177125  0.09405483], se: [0.04823404 0.01304062 0.01648886 0.00960113 0.00804395]
# [  1   3  10  50 100]
# index: 1,  x: [10 20 30 40 50], y: [ 56.80767073 103.59034567 151.60888506 196.80363801 244.7298129 ], se: [2.05934818 2.50124338 1.50856251 2.89102317 1.90728126]
# ...

# %%
import sys
import os

name = "20220909-061042-10-10-50-10-100-500-0-0.0-2.0-1.0-2.0-5.0-0.1"

if 'plotting' in sys.modules:  
    del sys.modules["plotting"]

from plotting import * 

method_list = ['TS-Bayes_errors','TS-Bayes_lambda_mins', 'TS-Bayes_lambda_maxs','TS-Bayes_log_maxs_over_mins', 'TS-Bayes_thinnesses',  'TS-Bayes_lambdas_second', 'TS-Bayes_lambdas_third', 'TS-Bayes_biases', 'TS-Bayes_variances','TS-Bayes_risks']



for method in method_list:
    save_path = f'../plots37/{method}/'
    isExist = os.path.exists(save_path)
    if not isExist:
        os.makedirs(save_path)

    df = pd.read_csv(f'../plots/all-unit-last-{name}.csv')
    plot_last_iter(df,'d' ,method,'d','y','k',save_path+name+'-1.jpg' )

    df = pd.read_csv(f'../plots/all-unit-{name}.csv')
    plot_sample_path(df, 'd', method, 't', 'y', 'd', 'k', save_path, f'{name}-2.jpg', 1)
# Out:
# [  1   3  10  50 100]
# index: 1,  x: [10 20 30 40 50], y: [0.0099248  0.00560158 0.00423696 0.00296224 0.00229424], se: [0.00213128 0.000614   0.00033828 0.00020431 0.00016638]
# index: 3,  x: [10 20 30 40 50], y: [0.0436353  0.01664253 0.01024097 0.0076677  0.00597417], se: [0.00629933 0.00178105 0.00099431 0.00041946 0.00044976]
# index: 10,  x: [10 20 30 40 50], y: [0.05938422 0.03061368 0.02688522 0.02194266 0.01565199], se: [0.00849298 0.00350862 0.00258995 0.00258571 0.00093701]
# index: 50,  x: [10 20 30 40 50], y: [0.20653904 0.10290034 0.08468441 0.06136682 0.04410437], se: [0.02444626 0.00922314 0.0062449  0.00437125 0.00318447]
# index: 100,  x: [10 20 30 40 50], y: [0.30725858 0.21335169 0.12353803 0.10112809 0.0761569 ], se: [0.05201045 0.02193103 0.01018369 0.01061786 0.00610962]
# [  1   3  10  50 100]
# index: 1,  x: [10 20 30 40 50], y: [ 57.05766973 103.84034467 151.85888406 197.05363701 244.9798119 ], se: [2.05934818 2.50124338 1.50856251 2.89102317 1.90728126]
# ...

# %%
import sys
import os

name = "20220909-063304-10-10-50-10-100-500-0-0.0-1000.0-1.0-2.0-5.0-0.1"

if 'plotting' in sys.modules:  
    del sys.modules["plotting"]

from plotting import * 

method_list = ['TS-Bayes_errors','TS-Bayes_lambda_mins', 'TS-Bayes_lambda_maxs','TS-Bayes_log_maxs_over_mins', 'TS-Bayes_thinnesses',  'TS-Bayes_lambdas_second', 'TS-Bayes_lambdas_third', 'TS-Bayes_biases', 'TS-Bayes_variances','TS-Bayes_risks']



for method in method_list:
    save_path = f'../pplots1/{method}/'
    isExist = os.path.exists(save_path)
    if not isExist:
        os.makedirs(save_path)

    df = pd.read_csv(f'../outputs2/all-unit-last-{name}.csv')
    plot_last_iter(df,'d' ,method,'d','y','k',save_path+name+'-1.jpg' )

    df = pd.read_csv(f'../outputs2/all-unit-{name}.csv')
    plot_sample_path(df, 'd', method, 't', 'y', 'd', 'k', save_path, f'{name}-2.jpg', 1)
# Out:
# [  1   3  10  50 100]
# index: 1,  x: [10 20 30 40 50], y: [ 349.34739589  614.28711213 1001.05363071 1219.89680665 1522.33862979], se: [39.68023728 88.72265245 85.03725733 79.90133864 78.22142482]
# index: 3,  x: [10 20 30 40 50], y: [ 352.06771834  621.76209241  886.77237415 1083.22978808 1549.11506514], se: [66.38678328 64.1796804  61.78158876 96.16911567 57.58274259]
# index: 10,  x: [10 20 30 40 50], y: [ 212.35033252  359.07618954  644.71528577  801.09644362 1039.883324  ], se: [19.67685568 25.85346099 29.68848947 65.84575926 46.54947593]
# index: 50,  x: [10 20 30 40 50], y: [139.85282573 256.96763638 433.22890261 625.91655564 611.06291492], se: [12.37462919 20.46851926 41.36963282 19.33684268 36.54285139]
# index: 100,  x: [10 20 30 40 50], y: [121.70942887 244.82154203 405.80141058 521.88437548 655.12308523], se: [16.76145343 24.53907961 42.33258866 48.10972218 49.39747739]
# [  1   3  10  50 100]
# ...

# %%
import sys
import os

name = "20220909-063258-10-10-50-10-100-500-0-0.0-2.0-1.0-2.0-5.0-0.1"

if 'plotting' in sys.modules:  
    del sys.modules["plotting"]

from plotting import * 

method_list = ['TS-Bayes_errors','TS-Bayes_lambda_mins', 'TS-Bayes_lambda_maxs','TS-Bayes_log_maxs_over_mins', 'TS-Bayes_thinnesses',  'TS-Bayes_lambdas_second', 'TS-Bayes_lambdas_third', 'TS-Bayes_biases', 'TS-Bayes_variances','TS-Bayes_risks']



for method in method_list:
    save_path = f'../pplots2/{method}/'
    isExist = os.path.exists(save_path)
    if not isExist:
        os.makedirs(save_path)

    df = pd.read_csv(f'../outputs2/all-unit-last-{name}.csv')
    plot_last_iter(df,'d' ,method,'d','y','k',save_path+name+'-1.jpg' )

    df = pd.read_csv(f'../outputs2/all-unit-{name}.csv')
    plot_sample_path(df, 'd', method, 't', 'y', 'd', 'k', save_path, f'{name}-2.jpg', 1)
# Out:
# [  1   3  10  50 100]
# index: 1,  x: [10 20 30 40 50], y: [ 5.13646137  8.81102399 13.58256562 15.98119155 20.35077257], se: [0.75056011 1.24962805 1.09419744 0.75939973 1.35891406]
# index: 3,  x: [10 20 30 40 50], y: [ 6.01241116 10.73667415 14.68350136 16.22549399 23.51673988], se: [0.73095702 0.87505887 1.49408525 1.24661161 1.25515176]
# index: 10,  x: [10 20 30 40 50], y: [ 6.04812614  7.93109204 11.65828516 18.27952753 19.57930004], se: [0.65012089 0.81356852 1.17105596 1.21978333 1.24428988]
# index: 50,  x: [10 20 30 40 50], y: [ 3.91242162  8.62487304 11.9103061  15.07821839 19.07047837], se: [0.42487815 0.86969305 0.9500721  1.28378759 0.80113329]
# index: 100,  x: [10 20 30 40 50], y: [ 6.55082864  9.62295911 13.57416917 18.66469739 20.80628519], se: [1.1547827  1.64655031 1.05495259 1.5219641  2.55508119]
# [  1   3  10  50 100]
# ...

# %%
import sys
import os

name = "20220913-173434-10-50-200-50-100-2000-0-0.0-1000.0-1.0-2.0-5.0-0.1"

if 'plotting' in sys.modules:  
    del sys.modules["plotting"]

from plotting import * 

method_list = ['TS-Bayes_errors','TS-Bayes_lambda_mins', 'TS-Bayes_lambda_maxs','TS-Bayes_log_maxs_over_mins', 'TS-Bayes_thinnesses',  'TS-Bayes_lambdas_second', 'TS-Bayes_lambdas_third', 'TS-Bayes_biases', 'TS-Bayes_variances','TS-Bayes_risks']



for method in method_list:
    save_path = f'../pplots3/{method}/'
    isExist = os.path.exists(save_path)
    if not isExist:
        os.makedirs(save_path)

    df = pd.read_csv(f'../outputs2/all-unit-last-{name}.csv')
    plot_last_iter(df,'d' ,method,'d','y','k',save_path+name+'-1.jpg' )

    df = pd.read_csv(f'../outputs2/all-unit-{name}.csv')
    plot_sample_path(df, 'd', method, 't', 'y', 'd', 'k', save_path, f'{name}-2.jpg', 1)
# Out:
# [  1   3  10  50 100]
# index: 1,  x: [ 50 100 150 200], y: [1658.79127261 3184.9548672  4590.16141869 5947.92443959], se: [101.22115919 120.94108253 173.78747931 180.44453496]
# index: 3,  x: [ 50 100 150 200], y: [1500.45153597 2981.65356235 4147.29781765 5203.09026756], se: [ 67.77680145 115.28195669 165.79925083 227.86642066]
# index: 10,  x: [ 50 100 150 200], y: [1019.02687466 1905.28826036 2622.5427824  3652.46895779], se: [ 72.11479441  98.24441845  95.60841895 110.49710969]
# index: 50,  x: [ 50 100 150 200], y: [ 700.91650688 1404.2588775  1957.97302649 2531.45396486], se: [38.82335189 63.65703729 68.22258878 74.98074434]
# index: 100,  x: [ 50 100 150 200], y: [ 568.44022031 1270.65125127 1727.55809519 2425.04743439], se: [30.65134525 56.03217172 64.96208484 56.25296972]
# [  1   3  10  50 100]
# index: 1,  x: [ 50 100 150 200], y: [0.01678663 0.01701753 0.01747478 0.01799207], se: [1.96085099e-04 6.98709749e-05 8.02777782e-05 5.49618811e-05]
# ...

# %%
import sys
import os

name = "20220913-173434-10-50-200-50-100-2000-0-0.0-1000.0-1.0-2.0-5.0-0.1"

if 'plotting' in sys.modules:  
    del sys.modules["plotting"]

from plotting import * 

method_list = ['TS-Bayes_errors','TS-Bayes_lambda_mins', 'TS-Bayes_lambda_maxs','TS-Bayes_log_maxs_over_mins', 'TS-Bayes_thinnesses',  'TS-Bayes_lambdas_second', 'TS-Bayes_lambdas_third', 'TS-Bayes_biases', 'TS-Bayes_variances','TS-Bayes_risks']



for method in method_list:
    save_path = f'../pplots3/{method}/'
    isExist = os.path.exists(save_path)
    if not isExist:
        os.makedirs(save_path)

    df = pd.read_csv(f'../outputs2/all-unit-last-{name}.csv')
    plot_last_iter(df,'d' ,method,'d','y','k',save_path+name+'-1.jpg' )

    df = pd.read_csv(f'../outputs2/all-unit-{name}.csv')
    plot_sample_path(df, 'd', method, 't', 'y', 'd', 'k', save_path, f'{name}-2.jpg', 1)

# %%
import sys
import os

name = "20220914-024118-10-50-200-50-1-2000-0-0.0-1000.0-1.0-2.0-5.0-0.1"

if 'plotting' in sys.modules:  
    del sys.modules["plotting"]

from plotting import * 

method_list = ['TS-Bayes_errors','TS-Bayes_lambda_mins', 'TS-Bayes_lambda_maxs','TS-Bayes_log_maxs_over_mins', 'TS-Bayes_thinnesses',  'TS-Bayes_lambdas_second', 'TS-Bayes_lambdas_third', 'TS-Bayes_biases', 'TS-Bayes_variances','TS-Bayes_risks']



for method in method_list:
    save_path = f'../pplots4/{method}/'
    isExist = os.path.exists(save_path)
    if not isExist:
        os.makedirs(save_path)

    df = pd.read_csv(f'../outputs2/all-unit-last-{name}.csv')
    plot_last_iter(df,'d' ,method,'d','y','k',save_path+name+'-1.jpg' )

    df = pd.read_csv(f'../outputs2/all-unit-{name}.csv')
    plot_sample_path(df, 'd', method, 't', 'y', 'd', 'k', save_path, f'{name}-2.jpg', 1)
# Out:
# [1]
# index: 1,  x: [ 50 100 150 200], y: [0.10431103 0.10695819 0.11565594 0.11428163], se: [0.0098035  0.00336249 0.00273192 0.00352464]
# [1]
# index: 1,  x: [ 50 100 150 200], y: [241.41493749 483.95209083 716.95695916 945.6660943 ], se: [2.22593236 3.12865424 2.275531   5.09620224]
# [1]
# index: 1,  x: [ 50 100 150 200], y: [ 836.12501592 1695.22657936 2552.1078874  3430.93719074], se: [ 4.25145985  7.40340968 11.37971049  8.23829834]
# [1]
# index: 1,  x: [ 50 100 150 200], y: [0.02789216 0.01536997 0.01094257 0.00861063], se: [2.46605567e-04 1.01464090e-04 3.76513271e-05 4.84137439e-05]
# [1]
# index: 1,  x: [ 50 100 150 200], y: [1.36808897 1.36450287 1.37228692 1.38011489], se: [0.00628311 0.00384364 0.00221386 0.00362536]
# [1]
# index: 1,  x: [ 50 100 150 200], y: [ 798.36132314 1650.41278358 2509.99962848 3380.60679273], se: [3.92477845 7.90062653 4.86819742 8.57969312]
# [1]
# ...

# %%
from turtle import color
import numpy as np
import numpy.linalg as npl 
import matplotlib.pyplot as plt
import matplotlib.cm as cm



# I'm taking an arbitrary symmetric matrix
XX = np.array( [[233.3034206, 178.64461062],
[178.64461062, 245.24271018]] )

center = np.array([10.47371708, 11.63760344])

center = center[np.newaxis,:]

#eigenvalues, eigenvectors = np.linalg.svd(,hermitian=True)
theta = np.linspace(0, 2*np.pi, 100);

svd = npl.svd(XX, hermitian=True)

# mean = svd[0] @ ((svd[2] @ self.xy) / svd[1])
basis = svd[2]
scale = svd[1]

unit_circle = np.array([np.sin(theta), np.cos(theta)])

ellipsis = basis.T @ (unit_circle.T / scale ** 0.5).T
ellipsis_inv = basis.T @ (unit_circle.T * scale ** 0.5).T

normalzied_ellipsis = ellipsis / np.linalg.norm(ellipsis, axis=0)
normalzied_ellipsis2 = (ellipsis+ center.T)/ np.linalg.norm(ellipsis+center.T, axis=0) 
second_ellipsis = basis.T @ (np.array(normalzied_ellipsis.T / scale ** 0.5)).T
second_ellipsis2 = basis.T @ (np.array(normalzied_ellipsis2.T / scale ** 0.5)).T
print(f"eigenvalues = {scale}, basis.T = {basis.T}")

colors = cm.rainbow(np.linspace(0, 1, len(theta)))

#ellipsis = eigenvectors.T @ (  np.array([np.sin(theta), np.cos(theta)])/ eigenvalues ** 0.5)
#ellipsis = (1/np.sqrt(eigenvalues[None,:]) * eigenvectors) @ [np.sin(theta), np.cos(theta)]

#normalzied_ellipsis = ellipsis / np.linalg.norm(ellipsis, axis=0)

#second_ellipsis = (1/np.sqrt(eigenvalues[None,:]) * eigenvectors)  @ normalzied_ellipsis

point_size = 0.5
figure_size = (6,6)




plt.close()
plt.figure(figsize=figure_size, dpi=200)

for unit,point,point_unit,point_unit2,point_snd, point_snd2, c in zip(unit_circle.T, ellipsis.T, normalzied_ellipsis.T, normalzied_ellipsis2.T,second_ellipsis.T,second_ellipsis2.T, colors):
    #print(point[0])
    plt.scatter(point[0] + center[0,0], point[1] + center[0,1], color=c, s = point_size)

    #plt.scatter(point_snd[0] + center[0], point_snd[1] + center[1], color=c, s = point_size)
    plt.scatter(unit[0], unit[1], color=c, s = point_size)
plt.plot([0,10.47371708/np.sqrt(2)/8], [0, 11.63760344/np.sqrt(2)/8],color = 'b')
plt.axis('equal')
plt.show()



plt.close()
plt.figure(figsize=figure_size, dpi=200)

for unit,point,point_unit,point_unit2,point_snd, point_snd2, c in zip(unit_circle.T, ellipsis.T, normalzied_ellipsis.T, normalzied_ellipsis2.T,second_ellipsis.T,second_ellipsis2.T, colors):
    #print(point[0])
    plt.scatter(point[0] , point[1] , color=c, s = point_size)
    plt.scatter(0.5*point_unit[0] , 0.5*point_unit[1], color=c, s = point_size)
    plt.scatter(0.5*point_unit2[0] , 0.5*point_unit2[1] , color=c, s = point_size)

    plt.scatter(unit[0], unit[1], color=c, s = point_size)
plt.plot([0,10.47371708/np.sqrt(2)/8], [0, 11.63760344/np.sqrt(2)/8],color = 'b')    
plt.axis('equal')
plt.show()




plt.close()
plt.figure(figsize=figure_size, dpi=200)
for unit,point,point_unit, point_unit2,point_snd, point_snd2, c in zip(unit_circle.T, ellipsis.T, normalzied_ellipsis.T, normalzied_ellipsis2.T,second_ellipsis.T,second_ellipsis2.T, colors):
    #print(point[0])
    plt.scatter(unit[0], unit[1], color=c, s = point_size)
    plt.scatter(0.5*point_unit[0] , 0.5*point_unit[1] , color=c, s = point_size)
    plt.scatter(0.5*point_unit2[0] , 0.5*point_unit2[1] , color=c, s = point_size)
    plt.scatter(point_snd[0] , point_snd[1], color=c, s = point_size)
    plt.scatter(point_snd2[0] , point_snd2[1], color=c, s = point_size)
    



    #plt.scatter(unit[0], unit[1], color=c, s = point_size)
plt.plot([0,10.47371708/np.sqrt(2)/8], [0, 11.63760344/np.sqrt(2)/8],color = 'b')
plt.axis('equal')

plt.show()

plt.close()
plt.figure(figsize=figure_size, dpi=200)

for point_inv,point, c in zip(ellipsis_inv.T, ellipsis.T, colors):
    #print(point[0])
    plt.scatter(point[0] + center[0,0], point[1] + center[0,1], color=c, s = point_size)

    #plt.scatter(point_snd[0] + center[0], point_snd[1] + center[1], color=c, s = point_size)
    plt.scatter(point_inv[0], point_inv[1], color=c, s = point_size)
plt.plot([0,10.47371708/np.sqrt(2)/8], [0, 11.63760344/np.sqrt(2)/8],color = 'b')
plt.axis('equal')
plt.show()
# Out:
# eigenvalues = [418.01738995  60.52874083], basis.T = [[ 0.69519865 -0.71881767]
#  [ 0.71881767  0.69519865]]

# %%
from turtle import color
import numpy as np
import numpy.linalg as npl 
import matplotlib.pyplot as plt
import matplotlib.cm as cm



# I'm taking an arbitrary symmetric matrix
XX = np.array( [[233.3034206, 1],
[1, 2]] )

center = np.array([10.47371708, 11.63760344])

center = center[np.newaxis,:]

#eigenvalues, eigenvectors = np.linalg.svd(,hermitian=True)
theta = np.linspace(0, 2*np.pi, 100);

svd = npl.svd(XX, hermitian=True)

# mean = svd[0] @ ((svd[2] @ self.xy) / svd[1])
basis = svd[2]
scale = svd[1]

unit_circle = np.array([np.sin(theta), np.cos(theta)])

ellipsis = basis.T @ (unit_circle.T / scale ** 0.5).T
ellipsis_inv = basis.T @ (unit_circle.T * scale ** 0.5).T

normalzied_ellipsis = ellipsis / np.linalg.norm(ellipsis, axis=0)
normalzied_ellipsis2 = (ellipsis+ center.T)/ np.linalg.norm(ellipsis+center.T, axis=0) 
second_ellipsis = basis.T @ (np.array(normalzied_ellipsis.T / scale ** 0.5)).T
second_ellipsis2 = basis.T @ (np.array(normalzied_ellipsis2.T / scale ** 0.5)).T
print(f"eigenvalues = {scale}, basis.T = {basis.T}")

colors = cm.rainbow(np.linspace(0, 1, len(theta)))

#ellipsis = eigenvectors.T @ (  np.array([np.sin(theta), np.cos(theta)])/ eigenvalues ** 0.5)
#ellipsis = (1/np.sqrt(eigenvalues[None,:]) * eigenvectors) @ [np.sin(theta), np.cos(theta)]

#normalzied_ellipsis = ellipsis / np.linalg.norm(ellipsis, axis=0)

#second_ellipsis = (1/np.sqrt(eigenvalues[None,:]) * eigenvectors)  @ normalzied_ellipsis

point_size = 0.5
figure_size = (6,6)




plt.close()
plt.figure(figsize=figure_size, dpi=200)

for unit,point,point_unit,point_unit2,point_snd, point_snd2, c in zip(unit_circle.T, ellipsis.T, normalzied_ellipsis.T, normalzied_ellipsis2.T,second_ellipsis.T,second_ellipsis2.T, colors):
    #print(point[0])
    plt.scatter(point[0] + center[0,0], point[1] + center[0,1], color=c, s = point_size)

    #plt.scatter(point_snd[0] + center[0], point_snd[1] + center[1], color=c, s = point_size)
    plt.scatter(unit[0], unit[1], color=c, s = point_size)
plt.plot([0,10.47371708/np.sqrt(2)/8], [0, 11.63760344/np.sqrt(2)/8],color = 'b')
plt.axis('equal')
plt.show()



plt.close()
plt.figure(figsize=figure_size, dpi=200)

for unit,point,point_unit,point_unit2,point_snd, point_snd2, c in zip(unit_circle.T, ellipsis.T, normalzied_ellipsis.T, normalzied_ellipsis2.T,second_ellipsis.T,second_ellipsis2.T, colors):
    #print(point[0])
    plt.scatter(point[0] , point[1] , color=c, s = point_size)
    #plt.scatter(0.5*point_unit[0] , 0.5*point_unit[1], color=c, s = point_size)
    plt.scatter(0.5*point_unit2[0] , 0.5*point_unit2[1] , color=c, s = point_size)

    plt.scatter(unit[0], unit[1], color=c, s = point_size)
plt.plot([0,10.47371708/np.sqrt(2)/8], [0, 11.63760344/np.sqrt(2)/8],color = 'b')    
plt.axis('equal')
plt.show()




plt.close()
plt.figure(figsize=figure_size, dpi=200)
for unit,point,point_unit, point_unit2,point_snd, point_snd2, c in zip(unit_circle.T, ellipsis.T, normalzied_ellipsis.T, normalzied_ellipsis2.T,second_ellipsis.T,second_ellipsis2.T, colors):
    #print(point[0])
    plt.scatter(unit[0], unit[1], color=c, s = point_size)
    #plt.scatter(0.5*point_unit[0] , 0.5*point_unit[1] , color=c, s = point_size)
    plt.scatter(0.5*point_unit2[0] , 0.5*point_unit2[1] , color=c, s = point_size)
    #plt.scatter(point_snd[0] , point_snd[1], color=c, s = point_size)
    plt.scatter(point_snd2[0] , point_snd2[1], color=c, s = point_size)
    



    #plt.scatter(unit[0], unit[1], color=c, s = point_size)
plt.plot([0,10.47371708/np.sqrt(2)/8], [0, 11.63760344/np.sqrt(2)/8],color = 'b')
plt.axis('equal')

plt.show()

plt.close()
plt.figure(figsize=figure_size, dpi=200)

for point_inv,point, c in zip(ellipsis_inv.T, ellipsis.T, colors):
    #print(point[0])
    plt.scatter(point[0] + center[0,0], point[1] + center[0,1], color=c, s = point_size)

    #plt.scatter(point_snd[0] + center[0], point_snd[1] + center[1], color=c, s = point_size)
    plt.scatter(point_inv[0], point_inv[1], color=c, s = point_size)
plt.plot([0,10.47371708/np.sqrt(2)/8], [0, 11.63760344/np.sqrt(2)/8],color = 'b')
plt.axis('equal')
plt.show()
# Out:
# eigenvalues = [233.30774384   1.99567676], basis.T = [[-0.99999065  0.0043232 ]
#  [-0.0043232  -0.99999065]]

# %%
normalzied_ellipsis.T
0.71881767**2 +  0.69519865**2
# Out:
# 1.0000000056660514

# %%
basis.T @ unit_circle
# Out:
# array([[-0.71881767, -0.1037812 ,  0.55981564,  0.96146852,  0.9132396 ,
#          0.43769571, -0.24265086, -0.8094584 , -0.99751136, -0.71881767],
#        [ 0.69519865,  0.99460015,  0.82861719,  0.27491503, -0.40742292,
#         -0.89912316, -0.97011368, -0.58717723,  0.07050597,  0.69519865]])

# %%
(unit_circle.T / scale ** 0.5)
# Out:
# array([[ 0.00000000e+00,  1.28534342e-01],
#        [ 3.14391157e-02,  9.84630188e-02],
#        [ 4.81675198e-02,  2.23197543e-02],
#        [ 4.23578060e-02, -6.42671712e-02],
#        [ 1.67284041e-02, -1.20782773e-01],
#        [-1.67284041e-02, -1.20782773e-01],
#        [-4.23578060e-02, -6.42671712e-02],
#        [-4.81675198e-02,  2.23197543e-02],
#        [-3.14391157e-02,  9.84630188e-02],
#        [-1.19796374e-17,  1.28534342e-01]])

# %%
unit_circle
# Out:
# array([[ 0.00000000e+00,  6.42787610e-01,  9.84807753e-01,
#          8.66025404e-01,  3.42020143e-01, -3.42020143e-01,
#         -8.66025404e-01, -9.84807753e-01, -6.42787610e-01,
#         -2.44929360e-16],
#        [ 1.00000000e+00,  7.66044443e-01,  1.73648178e-01,
#         -5.00000000e-01, -9.39692621e-01, -9.39692621e-01,
#         -5.00000000e-01,  1.73648178e-01,  7.66044443e-01,
#          1.00000000e+00]])

# %%
np.array([np.sin(theta), np.cos(theta)]).T
# Out:
# array([[ 0.00000000e+00,  1.00000000e+00],
#        [ 6.42787610e-01,  7.66044443e-01],
#        [ 9.84807753e-01,  1.73648178e-01],
#        [ 8.66025404e-01, -5.00000000e-01],
#        [ 3.42020143e-01, -9.39692621e-01],
#        [-3.42020143e-01, -9.39692621e-01],
#        [-8.66025404e-01, -5.00000000e-01],
#        [-9.84807753e-01,  1.73648178e-01],
#        [-6.42787610e-01,  7.66044443e-01],
#        [-2.44929360e-16,  1.00000000e+00]])

# %%
eigenvectors
# Out:
# array([[-0.71881767, -0.69519865],
#        [ 0.69519865, -0.71881767]])

# %%
np.array([np.sin(theta), np.cos(theta)]).T
# Out:
# array([[ 0.00000000e+00,  1.00000000e+00],
#        [ 6.34239197e-02,  9.97986676e-01],
#        [ 1.26592454e-01,  9.91954813e-01],
#        [ 1.89251244e-01,  9.81928697e-01],
#        [ 2.51147987e-01,  9.67948701e-01],
#        [ 3.12033446e-01,  9.50071118e-01],
#        [ 3.71662456e-01,  9.28367933e-01],
#        [ 4.29794912e-01,  9.02926538e-01],
#        [ 4.86196736e-01,  8.73849377e-01],
#        [ 5.40640817e-01,  8.41253533e-01],
#        [ 5.92907929e-01,  8.05270258e-01],
#        [ 6.42787610e-01,  7.66044443e-01],
#        [ 6.90079011e-01,  7.23734038e-01],
#        [ 7.34591709e-01,  6.78509412e-01],
#        [ 7.76146464e-01,  6.30552667e-01],
#        [ 8.14575952e-01,  5.80056910e-01],
#        [ 8.49725430e-01,  5.27225468e-01],
#        [ 8.81453363e-01,  4.72271075e-01],
#        [ 9.09631995e-01,  4.15415013e-01],
#        [ 9.34147860e-01,  3.56886222e-01],
#        [ 9.54902241e-01,  2.96920375e-01],
#        [ 9.71811568e-01,  2.35758936e-01],
# ...

# %%
plt.scatter(ellipsis[0,:], ellipsis[1,:],label = 'first')
plt.scatter(normalzied_ellipsis[0,:], normalzied_ellipsis[1,:],label = 'normalized')


plt.scatter(second_ellipsis[0,:], second_ellipsis[1,:],label = 'second')
plt.axis('equal')
# Out:
# array([[ 0.00000000e+00,  1.25781203e-02,  2.51512672e-02, ...,
#         -2.51512672e-02, -1.25781203e-02, -4.89858720e-16],
#        [ 1.00000000e+00,  9.99920892e-01,  9.99683657e-01, ...,
#          9.99683657e-01,  9.99920892e-01,  1.00000000e+00]])

# %%
theta
# Out:
# array([0.        , 0.06346652, 0.12693304, 0.19039955, 0.25386607,
#        0.31733259, 0.38079911, 0.44426563, 0.50773215, 0.57119866,
#        0.63466518, 0.6981317 , 0.76159822, 0.82506474, 0.88853126,
#        0.95199777, 1.01546429, 1.07893081, 1.14239733, 1.20586385,
#        1.26933037, 1.33279688, 1.3962634 , 1.45972992, 1.52319644,
#        1.58666296, 1.65012947, 1.71359599, 1.77706251, 1.84052903,
#        1.90399555, 1.96746207, 2.03092858, 2.0943951 , 2.15786162,
#        2.22132814, 2.28479466, 2.34826118, 2.41172769, 2.47519421,
#        2.53866073, 2.60212725, 2.66559377, 2.72906028, 2.7925268 ,
#        2.85599332, 2.91945984, 2.98292636, 3.04639288, 3.10985939,
#        3.17332591, 3.23679243, 3.30025895, 3.36372547, 3.42719199,
#        3.4906585 , 3.55412502, 3.61759154, 3.68105806, 3.74452458,
#        3.8079911 , 3.87145761, 3.93492413, 3.99839065, 4.06185717,
#        4.12532369, 4.1887902 , 4.25225672, 4.31572324, 4.37918976,
# ...

# %%
 (1/np.sqrt(eigenvalues[None,:]) * eigenvectors)
# Out:
# /var/folders/gs/mk2wx9yn4mxgrjsmlxbw_b3w0000gn/T/ipykernel_41278/3149268329.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   (1/np.sqrt(eigenvalues[None,:]) * eigenvectors)
# array([[-inf, -0.2],
#        [ inf, -0.4]])

# %%
from turtle import color
import numpy as np
import numpy.linalg as npl 
import matplotlib.pyplot as plt
import matplotlib.cm as cm



# I'm taking an arbitrary symmetric matrix
XX = np.array( [[233.3034206, 178.64461062],
[178.64461062, 245.24271018]] )

center = np.array([10.47371708, 11.63760344])

center = center[np.newaxis,:]

#eigenvalues, eigenvectors = np.linalg.svd(,hermitian=True)
theta = np.linspace(0, 2*np.pi, 100);

svd = npl.svd(XX, hermitian=True)

# mean = svd[0] @ ((svd[2] @ self.xy) / svd[1])
basis = svd[2]
scale = svd[1]

unit_circle = np.array([np.sin(theta), np.cos(theta)])

ellipsis = basis.T @ (unit_circle.T / scale ** 0.5).T
ellipsis_inv = basis.T @ (unit_circle.T * scale ** 0.5).T

normalzied_ellipsis = ellipsis / np.linalg.norm(ellipsis, axis=0)
normalzied_ellipsis2 = (ellipsis+ center.T)/ np.linalg.norm(ellipsis+center.T, axis=0) 
second_ellipsis = basis.T @ (np.array(normalzied_ellipsis.T / scale ** 0.5)).T
second_ellipsis2 = basis.T @ (np.array(normalzied_ellipsis2.T / scale ** 0.5)).T
print(f"eigenvalues = {scale}, basis.T = {basis.T}")

colors = cm.rainbow(np.linspace(0, 1, len(theta)))

#ellipsis = eigenvectors.T @ (  np.array([np.sin(theta), np.cos(theta)])/ eigenvalues ** 0.5)
#ellipsis = (1/np.sqrt(eigenvalues[None,:]) * eigenvectors) @ [np.sin(theta), np.cos(theta)]

#normalzied_ellipsis = ellipsis / np.linalg.norm(ellipsis, axis=0)

#second_ellipsis = (1/np.sqrt(eigenvalues[None,:]) * eigenvectors)  @ normalzied_ellipsis

point_size = 0.5
figure_size = (6,6)




plt.close()
plt.figure(figsize=figure_size, dpi=200)

for unit,point,point_unit,point_unit2,point_snd, point_snd2, c in zip(unit_circle.T, ellipsis.T, normalzied_ellipsis.T, normalzied_ellipsis2.T,second_ellipsis.T,second_ellipsis2.T, colors):
    #print(point[0])
    plt.scatter(point[0] + center[0,0], point[1] + center[0,1], color=c, s = point_size)

    #plt.scatter(point_snd[0] + center[0], point_snd[1] + center[1], color=c, s = point_size)
    plt.scatter(unit[0], unit[1], color=c, s = point_size)
plt.plot([0,10.47371708/np.sqrt(2)/8], [0, 11.63760344/np.sqrt(2)/8],color = 'b')
plt.axis('equal')
plt.show()



plt.close()
plt.figure(figsize=figure_size, dpi=200)

for unit,point,point_unit,point_unit2,point_snd, point_snd2, c in zip(unit_circle.T, ellipsis.T, normalzied_ellipsis.T, normalzied_ellipsis2.T,second_ellipsis.T,second_ellipsis2.T, colors):
    #print(point[0])
    plt.scatter(point[0] , point[1] , color=c, s = point_size)
    plt.scatter(0.5*point_unit[0] , 0.5*point_unit[1], color=c, s = point_size)
    plt.scatter(0.5*point_unit2[0] , 0.5*point_unit2[1] , color=c, s = point_size)

    plt.scatter(unit[0], unit[1], color=c, s = point_size)
plt.plot([0,10.47371708/np.sqrt(2)/8], [0, 11.63760344/np.sqrt(2)/8],color = 'b')    
plt.axis('equal')
plt.show()




plt.close()
plt.figure(figsize=figure_size, dpi=200)
for unit,point,point_unit, point_unit2,point_snd, point_snd2, c in zip(unit_circle.T, ellipsis.T, normalzied_ellipsis.T, normalzied_ellipsis2.T,second_ellipsis.T,second_ellipsis2.T, colors):
    #print(point[0])
    plt.scatter(unit[0], unit[1], color=c, s = point_size)
    plt.scatter(0.5*point_unit[0] , 0.5*point_unit[1] , color=c, s = point_size)
    plt.scatter(0.5*point_unit2[0] , 0.5*point_unit2[1] , color=c, s = point_size)
    plt.scatter(point_snd[0] , point_snd[1], color=c, s = point_size)
    plt.scatter(point_snd2[0] , point_snd2[1], color=c, s = point_size)
    



    #plt.scatter(unit[0], unit[1], color=c, s = point_size)
plt.plot([0,10.47371708/np.sqrt(2)/8], [0, 11.63760344/np.sqrt(2)/8],color = 'b')
plt.axis('equal')

plt.show()

plt.close()
plt.figure(figsize=figure_size, dpi=200)

for point_inv,point, c in zip(ellipsis_inv.T, ellipsis.T, colors):
    #print(point[0])
    plt.scatter(point[0] + center[0,0], point[1] + center[0,1], color=c, s = point_size)

    #plt.scatter(point_snd[0] + center[0], point_snd[1] + center[1], color=c, s = point_size)
    plt.scatter(point_inv[0], point_inv[1], color=c, s = point_size)
plt.plot([0,10.47371708/np.sqrt(2)/8], [0, 11.63760344/np.sqrt(2)/8],color = 'b')
plt.axis('equal')
plt.show()
# Out:
# eigenvalues = [418.01738995  60.52874083], basis.T = [[ 0.69519865 -0.71881767]
#  [ 0.71881767  0.69519865]]

# %%
from turtle import color
import numpy as np
import numpy.linalg as npl 
import matplotlib.pyplot as plt
import matplotlib.cm as cm



# I'm taking an arbitrary symmetric matrix
XX = np.array( [[233.3034206, 178.64461062],
[178.64461062, 245.24271018]] )
center = np.array([10.47371708, 11.63760344])
center = np.array([2**0.5/2 , 2**0.5/2])
center = np.array([0.2,-0.3])

center_normalized = center / np.linalg.norm(center)


new_center = ((center_normalized.T @ npl.inv( XX )@ center_normalized ) ** 0.5  + npl.norm(center)) *   center/npl.norm(center)


center = center[np.newaxis,:]

#eigenvalues, eigenvectors = np.linalg.svd(,hermitian=True)
theta = np.linspace(0, 2*np.pi, 100);

svd = npl.svd(XX, hermitian=True)

# mean = svd[0] @ ((svd[2] @ self.xy) / svd[1])
basis = svd[2]
scale = svd[1]

unit_circle = np.array([np.sin(theta), np.cos(theta)])

#ellipsis = basis.T @ (unit_circle.T / scale ** 0.5).T
ellipsis_inv = basis.T @ (unit_circle.T / scale ** 0.5).T



plt.close()
plt.figure(figsize=figure_size, dpi=200)
for unit,point, c in zip(unit_circle.T, ellipsis.T, colors):
    #print(point[0])
    plt.scatter(unit[0], unit[1], color=c, s = point_size)
    plt.scatter(point[0]+center[0,0], point[1]+center[0,1], color=c, s = point_size)

plt.scatter(new_center[0], new_center[1], color='b', s = point_size)
plt.scatter(center[0,0], center[0,1], color='b', s = point_size)
plt.scatter(0, 0, color='r', s = point_size)

# %%
new_center
# Out:
# array([21.15014168, 21.15014168])

# %%
center[0,0]
# Out:
# 0.7071067811865476
